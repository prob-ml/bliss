# %%
import galsim
import os
import matplotlib.pyplot as plt
os.chdir("/home/imendoza/deblend/galaxy-net")

# %%
#https://github.com/GalSim-developers/GalSim/wiki/RealGalaxy%20Data

rgc = galsim.RealGalaxyCatalog()

# %%
plt.imshow(rgc.getGalImage(3).array)

# %%
len(rgc)
# Out:
# 87798
