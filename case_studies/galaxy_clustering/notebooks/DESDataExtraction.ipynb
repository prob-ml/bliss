# %%
import case_studies.galaxy_clustering.data_generation.DES_data_extraction as des_extraction
import pandas as pd
from astropy.io import fits
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

# %%
columns = [
    "Cluster_ID",
    "Cluster_Name",
    "RA",
    "DEC",
    "z_cl",
    "BCG_i",
    "BCG_W1",
    "SNR",
    "r_500",
    "richness",
    "M_500",
    "N_500",
    "references",
]
catalog = pd.read_fwf(
    "/home/kapnadak/bliss/case_studies/galaxy_clustering/cluster_DESunWISE.dat", names=columns
)

# %%
mean_mass, std_mass = catalog["M_500"].mean(), catalog["M_500"].std()
mean_z, std_z = catalog["z_cl"].mean(), catalog["z_cl"].std()
mean_r, std_r = catalog["r_500"].mean(), catalog["r_500"].std()
mean_n, std_n = catalog["N_500"].mean(), catalog["N_500"].std()
print("Summary Statistics:")
print(f"Mean M500: {mean_mass}, Std M500: {std_mass}")
print(f"Mean r500: {mean_r}, Std r500: {std_r}")
print(f"Mean N500: {mean_n}, Std N500: {std_n}")
print(f"Mean z: {mean_z}, Std z: {std_z}")

# %%
catalog.sample(n=1)

# %% [markdown]
# # Experiment 1

# %%
bands = ["g", "r", "i", "z"]
ra, dec = 9.99503, -37.71075
z = 0.6743
m500 = 1.99 * 1e14
for band in bands:
    des_extraction.download_image(m500, z, ra, dec, band)

# %%
DES_DATAPATH = (
    "/home/kapnadak/bliss/case_studies/galaxy_clustering/data/DES_images/9.99503_-37.71075_g.fits"
)
hdu = fits.open(DES_DATAPATH)[0]
image = hdu.data
image = image[500:1780, 500:1780]
fig, ax = plt.subplots()
ax.imshow(image, norm=LogNorm(), origin="lower")

# %% [markdown]
# # Experiment 2

# %%
bands = ["g", "r", "i", "z"]
ra, dec, z = 6.62503, -41.86096, 0.2266
m500 = 1.23 * 1e14
for band in bands:
    des_extraction.download_image(m500, z, ra, dec, band, fov_scale=5)

# %%
DES_DATAPATH = (
    "/home/kapnadak/bliss/case_studies/galaxy_clustering/data/DES_images/6.62503_-41.86096_r.fits"
)
hdu = fits.open(DES_DATAPATH)[0]
image = hdu.data
image = image[500:1780, 500:1780]
fig, ax = plt.subplots()
ax.imshow(image, norm=LogNorm(), origin="lower")

# %% [markdown]
# # Experiment 3

# %%
bands = ["g", "r", "i", "z"]
ra, dec, z = 2.95916, -48.24259, 0.6861
m500 = 1.23 * 1e14
for band in bands:
    des_extraction.download_image(m500, z, ra, dec, band, fov_scale=6)

# %%
DES_DATAPATH = (
    "/home/kapnadak/bliss/case_studies/galaxy_clustering/data/DES_images/2.95916_-48.24259_r.fits"
)
hdu = fits.open(DES_DATAPATH)[0]
image = hdu.data
image = image[1270:, 0:1280]
fig, ax = plt.subplots()
ax.imshow(image, norm=LogNorm(), origin="lower")

# %% [markdown]
# # Experiment 4

# %%
bands = ["g", "r", "i", "z"]
ra, dec, z = 7.98499, -1.99208, 0.5142
m500 = 0.87 * 1e14
for band in bands:
    des_extraction.download_image(m500, z, ra, dec, band, fov_scale=6)

# %%
DES_DATAPATH = (
    "/home/kapnadak/bliss/case_studies/galaxy_clustering/data/DES_images/7.98499_-1.99208_g.fits"
)
hdu = fits.open(DES_DATAPATH)[0]
image = hdu.data
image = image[0:1280, 1000:2280]
fig, ax = plt.subplots()
ax.imshow(image, norm=LogNorm(), origin="lower")

# %% [markdown]
# # Experiment 5 (Random Coordinates)

# %%
bands = ["g", "r", "i", "z"]
ra, dec = 0.0220, -45.10023
z = 0.6064
m500 = 0.87 * 1e14
for band in bands:
    des_extraction.download_image(m500, z, ra, dec, band, fov_scale=6)

# %%
DES_DATAPATH = (
    "/home/kapnadak/bliss/case_studies/galaxy_clustering/data/DES_images/0.022_-45.10023_g.fits"
)
hdu = fits.open(DES_DATAPATH)[0]
image = hdu.data
image = image[0:1280, 0:1280]
fig, ax = plt.subplots()
ax.imshow(image, norm=LogNorm(), origin="lower")

# %% [markdown]
# # Experiment 6 (Random Coordinates)

# %%
bands = ["g", "r", "i", "z"]
ra, dec = 45.0228, -63.10023
z = 0.6064
m500 = 0.87 * 1e14
for band in bands:
    des_extraction.download_image(m500, z, ra, dec, band, fov_scale=6)

# %%
DES_DATAPATH = (
    "/home/kapnadak/bliss/case_studies/galaxy_clustering/data/DES_images/45.0228_-63.10023_g.fits"
)
hdu = fits.open(DES_DATAPATH)[0]
image = hdu.data
image = image[0:1280, 0:1280]
fig, ax = plt.subplots()
ax.imshow(image, norm=LogNorm(), origin="lower")

# %% [markdown]
# # Experiment 7 (Random Coordinates)

# %%
bands = ["g", "r", "i", "z"]
ra, dec = 60.01, -60.91
z = 0.6064
m500 = 0.87 * 1e14
for band in bands:
    des_extraction.download_image(m500, z, ra, dec, band, fov_scale=6)

# %%
DES_DATAPATH = (
    "/home/kapnadak/bliss/case_studies/galaxy_clustering/data/DES_images/60.01_-60.91_g.fits"
)
hdu = fits.open(DES_DATAPATH)[0]
image = hdu.data
image = image[0:1280, 0:1280]
fig, ax = plt.subplots()
ax.imshow(image, norm=LogNorm(), origin="lower")

# %% [markdown]
# # Experiment 8 (Random Coordinates)

# %%
bands = ["g", "r", "i", "z"]
ra, dec = 0, 0
z = 0.6064
m500 = 0.87 * 1e14
for band in bands:
    des_extraction.download_image(m500, z, ra, dec, band, fov_scale=6)

# %%
DES_DATAPATH = "/home/kapnadak/bliss/case_studies/galaxy_clustering/data/DES_images/0_0_g.fits"
hdu = fits.open(DES_DATAPATH)[0]
image = hdu.data
image = image[0:1280, 0:1280]
fig, ax = plt.subplots()
ax.imshow(image, norm=LogNorm(), origin="lower")
