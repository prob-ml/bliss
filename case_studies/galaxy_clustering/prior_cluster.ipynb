# %%
import sys
import os

# %%
# You should change this to your directory name
os.chdir('/home/shihangl/bliss')

# %%
from bliss.encoder.variational_dist import VariationalDistSpec, VariationalDist
from bliss.encoder.unconstrained_dists import UnconstrainedNormal
import torch
import numpy as np
from os import environ
from pathlib import Path
from hydra import initialize, compose
from hydra.utils import instantiate
import matplotlib.pyplot as plt
from omegaconf import DictConfig, OmegaConf
from bliss.catalog import TileCatalog

# %%
# Use our own config here
environ["BLISS_HOME"] = "/home/shihangl/bliss"
with initialize(config_path="../../case_studies/galaxy_clustering", version_base=None):
    cfg = compose("config", overrides={"surveys.sdss.load_image_data=true"})
# Out:
# ---------------------------------------------------------------------------
# MissingConfigException                    Traceback (most recent call last)
# Cell In[8], line 4
#       2 environ["BLISS_HOME"] = "/home/shihangl/bliss"
#       3 with initialize(config_path="../../case_studies/galaxy_clustering", version_base=None):
# ----> 4     cfg = compose("m2_config", overrides={"surveys.sdss.load_image_data=true"})
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/compose.py:38, in compose(config_name, overrides, return_hydra_config, strict)
#      36 gh = GlobalHydra.instance()
#      37 assert gh.hydra is not None
# ---> 38 cfg = gh.hydra.compose_config(
#      39     config_name=config_name,
#      40     overrides=overrides,
#      41     run_mode=RunMode.RUN,
#      42     from_shell=False,
#      43     with_log_configuration=False,
#      44 )
#      45 assert isinstance(cfg, DictConfig)
#      47 if not return_hydra_config:
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/hydra.py:594, in Hydra.compose_config(self, config_name, overrides, run_mode, with_log_configuration, from_shell, validate_sweep_overrides)
#     576 def compose_config(
#     577     self,
#     578     config_name: Optional[str],
#    (...)
#     583     validate_sweep_overrides: bool = True,
#     584 ) -> DictConfig:
#     585     """
#     586     :param config_name:
#     587     :param overrides:
#    (...)
#     591     :return:
#     592     """
# --> 594     cfg = self.config_loader.load_configuration(
#     595         config_name=config_name,
#     596         overrides=overrides,
#     597         run_mode=run_mode,
#     598         from_shell=from_shell,
#     599         validate_sweep_overrides=validate_sweep_overrides,
#     600     )
#     601     if with_log_configuration:
#     602         configure_log(cfg.hydra.hydra_logging, cfg.hydra.verbose)
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/config_loader_impl.py:142, in ConfigLoaderImpl.load_configuration(self, config_name, overrides, run_mode, from_shell, validate_sweep_overrides)
#     133 def load_configuration(
#     134     self,
#     135     config_name: Optional[str],
#    (...)
#     139     validate_sweep_overrides: bool = True,
#     140 ) -> DictConfig:
#     141     try:
# --> 142         return self._load_configuration_impl(
#     143             config_name=config_name,
#     144             overrides=overrides,
#     145             run_mode=run_mode,
#     146             from_shell=from_shell,
#     147             validate_sweep_overrides=validate_sweep_overrides,
#     148         )
#     149     except OmegaConfBaseException as e:
#     150         raise ConfigCompositionException().with_traceback(sys.exc_info()[2]) from e
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/config_loader_impl.py:253, in ConfigLoaderImpl._load_configuration_impl(self, config_name, overrides, run_mode, from_shell, validate_sweep_overrides)
#     248 if validate_sweep_overrides:
#     249     self.validate_sweep_overrides_legal(
#     250         overrides=parsed_overrides, run_mode=run_mode, from_shell=from_shell
#     251     )
# --> 253 defaults_list = create_defaults_list(
#     254     repo=caching_repo,
#     255     config_name=config_name,
#     256     overrides_list=parsed_overrides,
#     257     prepend_hydra=True,
#     258     skip_missing=run_mode == RunMode.MULTIRUN,
#     259 )
#     261 config_overrides = defaults_list.config_overrides
#     263 cfg = self._compose_config_from_defaults_list(
#     264     defaults=defaults_list.defaults, repo=caching_repo
#     265 )
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:745, in create_defaults_list(repo, config_name, overrides_list, prepend_hydra, skip_missing)
#     736 """
#     737 :param repo:
#     738 :param config_name:
#    (...)
#     742 :return:
#     743 """
#     744 overrides = Overrides(repo=repo, overrides_list=overrides_list)
# --> 745 defaults, tree = _create_defaults_list(
#     746     repo,
#     747     config_name,
#     748     overrides,
#     749     prepend_hydra=prepend_hydra,
#     750     skip_missing=skip_missing,
#     751 )
#     752 overrides.ensure_overrides_used()
#     753 overrides.ensure_deletions_used()
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:715, in _create_defaults_list(repo, config_name, overrides, prepend_hydra, skip_missing)
#     706 def _create_defaults_list(
#     707     repo: IConfigRepository,
#     708     config_name: Optional[str],
#    (...)
#     711     skip_missing: bool,
#     712 ) -> Tuple[List[ResultDefault], DefaultsTreeNode]:
#     713     root = _create_root(config_name=config_name, with_hydra=prepend_hydra)
# --> 715     defaults_tree = _create_defaults_tree(
#     716         repo=repo,
#     717         root=root,
#     718         overrides=overrides,
#     719         is_root_config=True,
#     720         interpolated_subtree=False,
#     721         skip_missing=skip_missing,
#     722     )
#     724     output = _tree_to_list(tree=defaults_tree)
#     725     ensure_no_duplicates_in_list(output)
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:356, in _create_defaults_tree(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     348 def _create_defaults_tree(
#     349     repo: IConfigRepository,
#     350     root: DefaultsTreeNode,
#    (...)
#     354     overrides: Overrides,
#     355 ) -> DefaultsTreeNode:
# --> 356     ret = _create_defaults_tree_impl(
#     357         repo=repo,
#     358         root=root,
#     359         is_root_config=is_root_config,
#     360         skip_missing=skip_missing,
#     361         interpolated_subtree=interpolated_subtree,
#     362         overrides=overrides,
#     363     )
#     365     return ret
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:457, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     455 if parent.is_virtual():
#     456     if is_root_config:
# --> 457         return _expand_virtual_root(repo, root, overrides, skip_missing)
#     458     else:
#     459         return root
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:280, in _expand_virtual_root(repo, root, overrides, skip_missing)
#     277 new_root = DefaultsTreeNode(node=d, parent=root)
#     278 d.update_parent("", "")
# --> 280 subtree = _create_defaults_tree_impl(
#     281     repo=repo,
#     282     root=new_root,
#     283     is_root_config=d.primary,
#     284     skip_missing=skip_missing,
#     285     interpolated_subtree=False,
#     286     overrides=overrides,
#     287 )
#     288 if subtree.children is None:
#     289     children.append(d)
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:464, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     462     root.node.update_parent("", "")
#     463     if not repo.config_exists(root.node.get_config_path()):
# --> 464         config_not_found_error(repo=repo, tree=root)
#     466 update_package_header(repo=repo, node=parent)
#     468 if overrides.is_deleted(parent):
#
# File ~/bliss/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:799, in config_not_found_error(repo, tree)
#     796 lines = "\n".join(descs)
#     797 msg += "\nConfig search path:" + f"\n{lines}"
# --> 799 raise MissingConfigException(
#     800     missing_cfg_file=element.get_config_path(),
#     801     message=msg,
#     802     options=options,
#     803 )
#
# MissingConfigException: Cannot find primary config 'm2_config'. Check that it's in your config search path.
#
# Config search path:
# 	provider=hydra, path=pkg://hydra.conf
# 	provider=main, path=file:///home/shihangl/bliss/case_studies/galaxy_clustering
# 	provider=schema, path=structured://

# %%
def generate(gen_cfg: DictConfig):
    simulated_dataset = instantiate(gen_cfg.simulator, num_workers=0)

    for _ in range(1):
        batch = simulated_dataset.get_batch()
        
    return batch

# %%
simulated_batch_of_data = generate(cfg.generate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 simulated_batch_of_data = generate(cfg.generate)
#
# Cell In[5], line 5, in generate(gen_cfg)
#       2 simulated_dataset = instantiate(gen_cfg.simulator, num_workers=0)
#       4 for _ in range(1):
# ----> 5     batch = simulated_dataset.get_batch()
#       7 return batch
#
# File ~/bliss/bliss/simulator/simulated_dataset.py:195, in SimulatedDataset.get_batch(self)
#     193 image_ids, image_id_indices = self.randomized_image_ids(self.catalog_prior.batch_size)
#     194 with torch.no_grad():
# --> 195     tile_catalog = self.catalog_prior.sample()
#     196     images, background, deconv, psf_params = self.simulate_images(
#     197         tile_catalog, image_ids, image_id_indices
#     198     )
#     199     return {
#     200         "tile_catalog": tile_catalog.to_dict(),
#     201         "images": images,
#    (...)
#     204         "psf_params": psf_params,
#     205     }
#
# File ~/bliss/case_studies/galaxy_clustering/prior.py:183, in GalaxyClusterPrior.sample(self)
#     181 cluster_types = torch.zeros((self.batch_size, max(self.n_batch_cluster_galaxy), 1))
#     182 # Generate their fluxes.
# --> 183 cluster_galaxy_fluxes, cluster_galaxy_params = self._sample_galaxy_prior_cluster(max(self.n_batch_cluster_galaxy), True)
#     184 # Max number of sources across all batches that may still left for other sources
#     186 max_left_n_sources = 0
#
# File ~/bliss/case_studies/galaxy_clustering/prior.py:90, in GalaxyClusterPrior._sample_galaxy_prior_cluster(self, max_source, cluster)
#      85 flux_prop = self._sample_flux_ratios_cluster(self.gmm_gal, max_source)
#      87 latent_dims = (self.batch_size, max_source, 1)
#      89 ref_band_flux = self._draw_truncated_pareto(
# ---> 90     self.galaxy_flux_exponent,
#      91     self.galaxy_flux_truncation,
#      92     self.galaxy_flux_loc,
#      93     self.galaxy_flux_scale,
#      94     latent_dims,
#      95 )
#      96 if cluster:
#      97     for i in range(self.batch_size):
#
# File ~/bliss/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1614, in Module.__getattr__(self, name)
#    1612     if name in modules:
#    1613         return modules[name]
# -> 1614 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1615     type(self).__name__, name))
#
# AttributeError: 'GalaxyClusterPrior' object has no attribute 'galaxy_flux_exponent'

# %%
ims = simulated_batch_of_data['images']

# %%
plt.imshow(ims[0][0]) #u-band for first image
