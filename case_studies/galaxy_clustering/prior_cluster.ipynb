# %%
import sys
import os

# %%
# You should change this to your directory name
os.chdir('/home/shihangl/bliss')

# %%
from bliss.encoder.variational_dist import VariationalDistSpec, VariationalDist
from bliss.encoder.unconstrained_dists import UnconstrainedNormal
import torch
import numpy as np
from os import environ
from pathlib import Path
from hydra import initialize, compose
from hydra.utils import instantiate
import matplotlib.pyplot as plt
from omegaconf import DictConfig, OmegaConf
from bliss.catalog import TileCatalog

# %%
# Use our own config here
environ["BLISS_HOME"] = "/home/shihangl/bliss"
with initialize(config_path="../../case_studies/galaxy_clustering", version_base=None):
    cfg = compose("config", overrides={"surveys.sdss.load_image_data=true"})

# %%
def generate(gen_cfg: DictConfig):
    simulated_dataset = instantiate(gen_cfg.simulator, num_workers=0)

    for _ in range(1):
        batch = simulated_dataset.get_batch()
        
    return batch

# %%
simulated_batch_of_data = generate(cfg.generate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 simulated_batch_of_data = generate(cfg.generate)
#
# Cell In[5], line 5, in generate(gen_cfg)
#       2 simulated_dataset = instantiate(gen_cfg.simulator, num_workers=0)
#       4 for _ in range(1):
# ----> 5     batch = simulated_dataset.get_batch()
#       7 return batch
#
# File ~/bliss/bliss/simulator/simulated_dataset.py:195, in SimulatedDataset.get_batch(self)
#     193 image_ids, image_id_indices = self.randomized_image_ids(self.catalog_prior.batch_size)
#     194 with torch.no_grad():
# --> 195     tile_catalog = self.catalog_prior.sample()
#     196     images, background, deconv, psf_params = self.simulate_images(
#     197         tile_catalog, image_ids, image_id_indices
#     198     )
#     199     return {
#     200         "tile_catalog": tile_catalog.to_dict(),
#     201         "images": images,
#    (...)
#     204         "psf_params": psf_params,
#     205     }
#
# File ~/bliss/case_studies/galaxy_clustering/prior.py:180, in GalaxyClusterPrior.sample(self)
#     178 cluster_types = torch.zeros((self.batch_size, max(self.n_batch_cluster_galaxy), 1))
#     179 # Generate their fluxes.
# --> 180 cluster_galaxy_fluxes, cluster_galaxy_params = self._sample_galaxy_prior_cluster(max(self.n_batch_cluster_galaxy), True)
#     181 # Max number of sources across all batches that may still left for other sources
#     183 max_left_n_sources = 0
#
# File ~/bliss/case_studies/galaxy_clustering/prior.py:90, in GalaxyClusterPrior._sample_galaxy_prior_cluster(self, max_source, cluster)
#      85 flux_prop = self._sample_flux_ratios_cluster(self.gmm_gal, max_source)
#      87 latent_dims = (self.batch_size, max_source, 1)
#      89 ref_band_flux = self._draw_truncated_pareto(
# ---> 90     self.galaxy_flux_exponent,
#      91     self.galaxy_flux_truncation,
#      92     self.galaxy_flux_loc,
#      93     self.galaxy_flux_scale,
#      94     latent_dims,
#      95 )
#      96 if cluster:
#      97     for i in range(self.batch_size):
#
# File ~/bliss/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1614, in Module.__getattr__(self, name)
#    1612     if name in modules:
#    1613         return modules[name]
# -> 1614 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1615     type(self).__name__, name))
#
# AttributeError: 'GalaxyClusterPrior' object has no attribute 'galaxy_flux_exponent'

# %%
ims = simulated_batch_of_data['images']

# %%
plt.imshow(ims[0][0]) #u-band for first image
