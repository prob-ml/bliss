# %% [markdown]
# ### Average ellipticity as an estimator for shear in DC2

# %% [markdown]
# In this notebook, we assess whether the average ellipticity of neighboring galaxies is a reasonable baseline estimator for the average shear in a tile.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import torch
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# First, we'll do some exploratory analysis of shear and ellipticity.
#
# We unpack the `from_file` method of `LensingDC2Catalog` (which can be found in `lensing_dc2.py`) to read in a DC2 catalog and convert unlensed ellipticites to lensed ellipticities. We use the same calculation as [this notebook](https://github.com/LSSTDESC/DC2-analysis/blob/master/tutorials/matching_fof.ipynb).

# %%
catalog_full = pd.read_pickle('/data/scratch/dc2local/dc2_lensing_catalog.pkl')

# %%
# for computational efficiency, we use a subset of the above data frame
catalog = catalog_full.sample(n = 100000)

# %%
galid = torch.from_numpy(catalog["galaxy_id"].values)
ra = torch.from_numpy(catalog["ra"].values).squeeze()
dec = torch.from_numpy(catalog["dec"].values).squeeze()

shear1 = torch.from_numpy(catalog["shear_1"].values).squeeze()
shear2 = torch.from_numpy(catalog["shear_2"].values).squeeze()
convergence = torch.from_numpy(catalog["convergence"].values)

ellip1_intrinsic = torch.from_numpy(catalog["ellipticity_1_true_dc2"].values).squeeze()
ellip2_intrinsic = torch.from_numpy(catalog["ellipticity_2_true_dc2"].values).squeeze()
ellip_intrinsic = torch.sqrt(ellip1_intrinsic ** 2 + ellip2_intrinsic ** 2)

complex_shear = shear1 + shear2 * 1j
complex_ellip = ellip1_intrinsic + ellip2_intrinsic * 1j
reduced_shear = complex_shear / (1.0 - convergence)
ellip_lensed = (complex_ellip + reduced_shear) / (1.0 + reduced_shear.conj() * complex_ellip)
ellip1_lensed = torch.view_as_real(ellip_lensed)[...,0]
ellip2_lensed = torch.view_as_real(ellip_lensed)[...,1]
ellip_lensed = torch.absolute(ellip_lensed)

# %% [markdown]
# We see that shear1 and shear2 are each approximately $\mathcal{N}(0, 0.015^2)$, and that they are essentially uncorrelated:

# %%
fig, ax = plt.subplots(1, 3, figsize = (12,4))
_ = ax[0].hist(shear1, bins = 100)
_ = ax[0].set_xlabel('shear1')
_ = ax[1].hist(shear2, bins = 100)
_ = ax[1].set_xlabel('shear2')
_ = ax[2].scatter(shear1, shear2, alpha = 0.05)
_ = ax[2].set_xlabel('shear1')
_ = ax[2].set_ylabel('shear2')
fig.tight_layout()

# %% [markdown]
# And we find that the two components of lensed ellipticity are each symmetrically distributed around zero, and that they are uncorrelated:

# %%
fig, ax = plt.subplots(1, 3, figsize = (12,4))
_ = ax[0].hist(ellip1_lensed, bins = 100)
_ = ax[0].set_xlabel('ellip1_lensed')
_ = ax[1].hist(ellip2_lensed, bins = 100)
_ = ax[1].set_xlabel('ellip2_lensed')
_ = ax[2].scatter(ellip1_lensed, ellip2_lensed, alpha = 0.05)
_ = ax[2].set_xlabel('ellip1_lensed')
_ = ax[2].set_ylabel('ellip2_lensed')
fig.tight_layout()

# %% [markdown]
# Next, we note that the effect of shear on ellipticity is very small, as the intrinsic and lensed ellipticity are very similar for both components:

# %%
fig, ax = plt.subplots(1, 2, figsize = (8,4))
_ = ax[0].scatter(ellip1_intrinsic, ellip1_lensed, alpha = 0.01)
_ = ax[0].set_xlabel('ellip1_intrinsic')
_ = ax[0].set_ylabel('ellip1_lensed')
_ = ax[1].scatter(ellip2_intrinsic, ellip2_lensed, alpha = 0.01)
_ = ax[1].set_xlabel('ellip2_intrinsic')
_ = ax[1].set_ylabel('ellip2_lensed')
fig.tight_layout()

# %% [markdown]
# And finally, we confirm that as the magnitude of shear increases, the absolute difference between the lensed and unlensed ellipticities also tends to increase:

# %%
fig, ax = plt.subplots(1, 2, figsize = (8,4))
_ = ax[0].scatter(shear1, (ellip1_lensed - ellip1_intrinsic).abs(), alpha = 0.01)
_ = ax[0].set_xlabel('shear1')
_ = ax[0].set_ylabel('| ellip1_lensed - ellip1_intrinsic |')
_ = ax[1].scatter(shear2, (ellip2_lensed - ellip2_intrinsic).abs(), alpha = 0.01)
_ = ax[1].set_xlabel('shear2')
_ = ax[1].set_ylabel('| ellip2_lensed - ellip2_intrinsic |')
fig.tight_layout()

# %% [markdown]
# ---

# %% [markdown]
# Our ground truth shear maps for DC2 are 8x8 grids of 256x256 pixel tiles, where the value of shear1 (or shear2) in each tile is the average shear1 (or shear2) of galaxies in that tile.
#
# As a baseline estimator for the average shear in each tile $T$, we compute a weighted average of the lensed ellipticities in tile $T$ and some number of adjacent tiles. To compute this weighted average, we apply a Gaussian kernel with size $s$ and standard deviation $\sigma$. We've implemented this estimator in `case_studies/weak_lensing/utils/weighted_avg_ellip.py`.
#
# Below, we tune $s$ and $\sigma$ by trying out several combinations and computing the resulting MSEs for shear1 and shear2.

# %%
import os
from hydra import initialize, compose
from hydra.utils import instantiate

import pytorch_lightning as pl
from pytorch_lightning.utilities import move_data_to_device

from bliss.global_env import GlobalEnv
from bliss.surveys.dc2 import DC2DataModule
from case_studies.weak_lensing.utils.weighted_avg_ellip import compute_weighted_avg_ellip

device = torch.device("cuda:6" if torch.cuda.is_available() else "cpu")

# %%
ckpt = "/data/scratch/twhit/checkpoints/trained_encoder_dc2.ckpt"

with initialize(config_path="../", version_base=None):
    cfg = compose("config_dc2", {
        "train.pretrained_weights=" + ckpt,
        })

seed = pl.seed_everything(cfg.train.seed)
GlobalEnv.seed_in_this_program = seed
GlobalEnv.current_encoder_epoch = 0
# Out:
# Seed set to 123123

# %%
data_source = instantiate(cfg.train.data_source)
data_source.setup("fit")
train_dl = data_source.train_dataloader()

# %%
train_data = []
for batch in train_dl:
    train_data.append(batch)

# %% [markdown]
# When the kernel size is 1, the estimator just computes the average ellipticity of galaxies in tile $T$ and does not use any of the surrounding tiles.
#
# When the kernel size is 15, the estimator uses the ellipiticities of the galaxies in all 8x8 tiles to compute its shear estimate in every tile $T$, even if tile $T$ is a corner tile.

# %%
kernel_sizes = [1,3,5,7,9,11,13,15]
kernel_sigmas = [1,3,5,7,9,11,13,15]

# %%
num_batches = len(train_data)

shear1 = torch.zeros(num_batches, 64)
shear2 = torch.zeros(num_batches, 64)
ellip1 = torch.zeros(len(kernel_sizes), len(kernel_sigmas), num_batches, 64)
ellip2 = torch.zeros(len(kernel_sizes), len(kernel_sigmas), num_batches, 64)
mse1 = torch.zeros(len(kernel_sizes), len(kernel_sigmas))
corr1 = torch.zeros(len(kernel_sizes), len(kernel_sigmas))
mse2 = torch.zeros(len(kernel_sizes), len(kernel_sigmas))
corr2 = torch.zeros(len(kernel_sizes), len(kernel_sigmas))

# %%
for j in range(len(kernel_sizes)):
    for k in range(len(kernel_sigmas)):
        print(f'kernel size = {kernel_sizes[j]}, kernel sigma = {kernel_sigmas[k]}')
        
        for i in range(num_batches):
            tile_cat = DC2DataModule.squeeze_tile_dict(train_data[i]['tile_catalog'])
            
            shear1[i] = tile_cat['shear_1'].flatten()
            shear2[i] = tile_cat['shear_2'].flatten()
            
            ellip_lsst_wavg = compute_weighted_avg_ellip(tile_cat, kernel_size = kernel_sizes[j], kernel_sigma = kernel_sigmas[k])

            ellip1[j,k,i] = ellip_lsst_wavg[...,0].flatten()
            ellip2[j,k,i] = ellip_lsst_wavg[...,1].flatten()
        
        mse1[j,k] = ((ellip1[j,k] - shear1)**2).mean()
        corr1[j,k] = np.corrcoef(ellip1[j,k].flatten(), shear1.flatten())[1,0]
        mse2[j,k] = ((ellip2[j,k] - shear2)**2).mean()
        corr2[j,k] = np.corrcoef(ellip2[j,k].flatten(), shear2.flatten())[1,0]
        
        print(f'MSE for shear 1 = {mse1[j,k]}')
        print(f'corr coef for shear 1 = {corr1[j,k]}')
        print(f'MSE for shear 2 = {mse2[j,k]}')
        print(f'corr coef for shear 2 = {corr2[j,k]}\n')
# Out:
# kernel size = 1, kernel sigma = 1
# MSE for shear 1 = 0.000394217437133193
# corr coef for shear 1 = -0.00834792573004961
# MSE for shear 2 = 0.00038401316851377487
# corr coef for shear 2 = -0.005224714521318674
#
# kernel size = 1, kernel sigma = 3
# MSE for shear 1 = 0.000394217437133193
# corr coef for shear 1 = -0.00834792573004961
# MSE for shear 2 = 0.00038401316851377487
# corr coef for shear 2 = -0.005224714521318674
#
# kernel size = 1, kernel sigma = 5
# MSE for shear 1 = 0.000394217437133193
# corr coef for shear 1 = -0.00834792573004961
# MSE for shear 2 = 0.00038401316851377487
# corr coef for shear 2 = -0.005224714521318674
#
# kernel size = 1, kernel sigma = 7
# MSE for shear 1 = 0.000394217437133193
# corr coef for shear 1 = -0.00834792573004961
# MSE for shear 2 = 0.00038401316851377487
# corr coef for shear 2 = -0.005224714521318674
#
# kernel size = 1, kernel sigma = 9
# MSE for shear 1 = 0.000394217437133193
# corr coef for shear 1 = -0.00834792573004961
# MSE for shear 2 = 0.00038401316851377487
# corr coef for shear 2 = -0.005224714521318674
#
# kernel size = 1, kernel sigma = 11
# MSE for shear 1 = 0.000394217437133193
# corr coef for shear 1 = -0.00834792573004961
# MSE for shear 2 = 0.00038401316851377487
# corr coef for shear 2 = -0.005224714521318674
#
# kernel size = 1, kernel sigma = 13
# MSE for shear 1 = 0.000394217437133193
# corr coef for shear 1 = -0.00834792573004961
# MSE for shear 2 = 0.00038401316851377487
# corr coef for shear 2 = -0.005224714521318674
#
# kernel size = 1, kernel sigma = 15
# MSE for shear 1 = 0.000394217437133193
# corr coef for shear 1 = -0.00834792573004961
# MSE for shear 2 = 0.00038401316851377487
# corr coef for shear 2 = -0.005224714521318674
#
# kernel size = 3, kernel sigma = 1
# MSE for shear 1 = 0.00012363048153929412
# corr coef for shear 1 = -0.01573534682393074
# MSE for shear 2 = 0.00011459614324849099
# corr coef for shear 2 = -0.01143661979585886
#
# kernel size = 3, kernel sigma = 3
# MSE for shear 1 = 0.00011807734699686989
# corr coef for shear 1 = -0.013590505346655846
# MSE for shear 2 = 0.00010916023893514648
# corr coef for shear 2 = -0.012254426255822182
#
# kernel size = 3, kernel sigma = 5
# MSE for shear 1 = 0.00011801453365478665
# corr coef for shear 1 = -0.013342104852199554
# MSE for shear 2 = 0.00010910839773714542
# corr coef for shear 2 = -0.0122843561694026
#
# kernel size = 3, kernel sigma = 7
# MSE for shear 1 = 0.00011800626816693693
# corr coef for shear 1 = -0.013272162526845932
# MSE for shear 2 = 0.00010910317359957844
# corr coef for shear 2 = -0.012291671708226204
#
# kernel size = 3, kernel sigma = 9
# MSE for shear 1 = 0.00011800397624028847
# corr coef for shear 1 = -0.01324320025742054
# MSE for shear 2 = 0.00010910214768955484
# corr coef for shear 2 = -0.012294567190110683
#
# kernel size = 3, kernel sigma = 11
# MSE for shear 1 = 0.00011800308129750192
# corr coef for shear 1 = -0.01322850026190281
# MSE for shear 2 = 0.0001091018712031655
# corr coef for shear 2 = -0.01229600515216589
#
# kernel size = 3, kernel sigma = 13
# MSE for shear 1 = 0.00011800263018812984
# corr coef for shear 1 = -0.01322003360837698
# MSE for shear 2 = 0.00010910180571954697
# corr coef for shear 2 = -0.0122968265786767
#
# kernel size = 3, kernel sigma = 15
# MSE for shear 1 = 0.00011800237552961335
# corr coef for shear 1 = -0.013214715756475925
# MSE for shear 2 = 0.00010910177661571652
# corr coef for shear 2 = -0.012297338806092739
#
# kernel size = 5, kernel sigma = 1
# MSE for shear 1 = 0.00010955719335470349
# corr coef for shear 1 = -0.016265710815787315
# MSE for shear 2 = 0.00010066793765872717
# corr coef for shear 2 = -0.013483257032930851
#
# kernel size = 5, kernel sigma = 3
# MSE for shear 1 = 9.281708480557427e-05
# corr coef for shear 1 = -0.010334585793316364
# MSE for shear 2 = 8.446998981526121e-05
# corr coef for shear 2 = -0.01652514934539795
#
# kernel size = 5, kernel sigma = 5
# MSE for shear 1 = 9.247773414244875e-05
# corr coef for shear 1 = -0.009249351918697357
# MSE for shear 2 = 8.418948709731922e-05
# corr coef for shear 2 = -0.016301441937685013
#
# kernel size = 5, kernel sigma = 7
# MSE for shear 1 = 9.242458327207714e-05
# corr coef for shear 1 = -0.00893582496792078
# MSE for shear 2 = 8.415318006882444e-05
# corr coef for shear 2 = -0.016214510425925255
#
# kernel size = 5, kernel sigma = 9
# MSE for shear 1 = 9.240797953680158e-05
# corr coef for shear 1 = -0.00880518089979887
# MSE for shear 2 = 8.414359763264656e-05
# corr coef for shear 2 = -0.016175471246242523
#
# kernel size = 5, kernel sigma = 11
# MSE for shear 1 = 9.240075451089069e-05
# corr coef for shear 1 = -0.008738706819713116
# MSE for shear 2 = 8.413995237788185e-05
# corr coef for shear 2 = -0.016154978424310684
#
# kernel size = 5, kernel sigma = 13
# MSE for shear 1 = 9.239697101293132e-05
# corr coef for shear 1 = -0.008700371719896793
# MSE for shear 2 = 8.41382279759273e-05
# corr coef for shear 2 = -0.016142969951033592
#
# kernel size = 5, kernel sigma = 15
# MSE for shear 1 = 9.239473001798615e-05
# corr coef for shear 1 = -0.00867628026753664
# MSE for shear 2 = 8.413728937739506e-05
# corr coef for shear 2 = -0.016135351732373238
#
# kernel size = 7, kernel sigma = 1
# MSE for shear 1 = 0.00010868773824768141
# corr coef for shear 1 = -0.016263535246253014
# MSE for shear 2 = 9.980232425732538e-05
# corr coef for shear 2 = -0.013773222453892231
#
# kernel size = 7, kernel sigma = 3
# MSE for shear 1 = 8.531314961146563e-05
# corr coef for shear 1 = -0.009613798931241035
# MSE for shear 2 = 7.693004590691999e-05
# corr coef for shear 2 = -0.019313998520374298
#
# kernel size = 7, kernel sigma = 5
# MSE for shear 1 = 8.4634855738841e-05
# corr coef for shear 1 = -0.008570488542318344
# MSE for shear 2 = 7.625052967341617e-05
# corr coef for shear 2 = -0.018012214452028275
#
# kernel size = 7, kernel sigma = 7
# MSE for shear 1 = 8.453964255750179e-05
# corr coef for shear 1 = -0.008299478329718113
# MSE for shear 2 = 7.615151844220236e-05
# corr coef for shear 2 = -0.017489541321992874
#
# kernel size = 7, kernel sigma = 9
# MSE for shear 1 = 8.451339817838743e-05
# corr coef for shear 1 = -0.008191093802452087
# MSE for shear 2 = 7.612326589878649e-05
# corr coef for shear 2 = -0.017252925783395767
#
# kernel size = 7, kernel sigma = 11
# MSE for shear 1 = 8.450309542240575e-05
# corr coef for shear 1 = -0.008137003518640995
# MSE for shear 2 = 7.611186447320506e-05
# corr coef for shear 2 = -0.0171283558011055
#
# kernel size = 7, kernel sigma = 13
# MSE for shear 1 = 8.44980968395248e-05
# corr coef for shear 1 = -0.00810613576322794
# MSE for shear 2 = 7.610619650222361e-05
# corr coef for shear 2 = -0.017055246978998184
#
# kernel size = 7, kernel sigma = 15
# MSE for shear 1 = 8.449530287180096e-05
# corr coef for shear 1 = -0.008086866699159145
# MSE for shear 2 = 7.610298780491576e-05
# corr coef for shear 2 = -0.017008837312459946
#
# kernel size = 9, kernel sigma = 1
# MSE for shear 1 = 0.00010866532829822972
# corr coef for shear 1 = -0.016266919672489166
# MSE for shear 2 = 9.978013986255974e-05
# corr coef for shear 2 = -0.013776518404483795
#
# kernel size = 9, kernel sigma = 3
# MSE for shear 1 = 8.226609497796744e-05
# corr coef for shear 1 = -0.012631448917090893
# MSE for shear 2 = 7.3894792876672e-05
# corr coef for shear 2 = -0.019064785912632942
#
# kernel size = 9, kernel sigma = 5
# MSE for shear 1 = 8.11716599855572e-05
# corr coef for shear 1 = -0.013362538069486618
# MSE for shear 2 = 7.276669202838093e-05
# corr coef for shear 2 = -0.016949808225035667
#
# kernel size = 9, kernel sigma = 7
# MSE for shear 1 = 8.102250285446644e-05
# corr coef for shear 1 = -0.013672105967998505
# MSE for shear 2 = 7.260085840243846e-05
# corr coef for shear 2 = -0.016136523336172104
#
# kernel size = 9, kernel sigma = 9
# MSE for shear 1 = 8.098495163721964e-05
# corr coef for shear 1 = -0.013810801319777966
# MSE for shear 2 = 7.255551463458687e-05
# corr coef for shear 2 = -0.015776075422763824
#
# kernel size = 9, kernel sigma = 11
# MSE for shear 1 = 8.097163663478568e-05
# corr coef for shear 1 = -0.013883200474083424
# MSE for shear 2 = 7.253805233631283e-05
# corr coef for shear 2 = -0.015588377602398396
#
# kernel size = 9, kernel sigma = 13
# MSE for shear 1 = 8.096576493699104e-05
# corr coef for shear 1 = -0.01392545085400343
# MSE for shear 2 = 7.252973591675982e-05
# corr coef for shear 2 = -0.01547891553491354
#
# kernel size = 9, kernel sigma = 15
# MSE for shear 1 = 8.096275996649638e-05
# corr coef for shear 1 = -0.013952177949249744
# MSE for shear 2 = 7.252518116729334e-05
# corr coef for shear 2 = -0.015409691259264946
#
# kernel size = 11, kernel sigma = 1
# MSE for shear 1 = 0.00010866512457141653
# corr coef for shear 1 = -0.016266943886876106
# MSE for shear 2 = 9.977993613574654e-05
# corr coef for shear 2 = -0.013776563107967377
#
# kernel size = 11, kernel sigma = 3
# MSE for shear 1 = 8.094328950392082e-05
# corr coef for shear 1 = -0.014126948080956936
# MSE for shear 2 = 7.270541391335428e-05
# corr coef for shear 2 = -0.02009238488972187
#
# kernel size = 11, kernel sigma = 5
# MSE for shear 1 = 7.939429633552209e-05
# corr coef for shear 1 = -0.016295211389660835
# MSE for shear 2 = 7.120631926227361e-05
# corr coef for shear 2 = -0.01872219704091549
#
# kernel size = 11, kernel sigma = 7
# MSE for shear 1 = 7.917021139292046e-05
# corr coef for shear 1 = -0.01706494390964508
# MSE for shear 2 = 7.098921196302399e-05
# corr coef for shear 2 = -0.018183710053563118
#
# kernel size = 11, kernel sigma = 9
# MSE for shear 1 = 7.911371358204633e-05
# corr coef for shear 1 = -0.01738858036696911
# MSE for shear 2 = 7.093432213878259e-05
# corr coef for shear 2 = -0.017948361113667488
#
# kernel size = 11, kernel sigma = 11
# MSE for shear 1 = 7.909397390903905e-05
# corr coef for shear 1 = -0.017552178353071213
# MSE for shear 2 = 7.091506995493546e-05
# corr coef for shear 2 = -0.017826955765485764
#
# kernel size = 11, kernel sigma = 13
# MSE for shear 1 = 7.908545376267284e-05
# corr coef for shear 1 = -0.01764593832194805
# MSE for shear 2 = 7.090674625942484e-05
# corr coef for shear 2 = -0.017756564542651176
#
# kernel size = 11, kernel sigma = 15
# MSE for shear 1 = 7.908119732746854e-05
# corr coef for shear 1 = -0.017704572528600693
# MSE for shear 2 = 7.090255530783907e-05
# corr coef for shear 2 = -0.01771220564842224
#
# kernel size = 13, kernel sigma = 1
# MSE for shear 1 = 0.00010866512457141653
# corr coef for shear 1 = -0.016266943886876106
# MSE for shear 2 = 9.977993613574654e-05
# corr coef for shear 2 = -0.013776563107967377
#
# kernel size = 13, kernel sigma = 3
# MSE for shear 1 = 8.043154230108485e-05
# corr coef for shear 1 = -0.0147585803642869
# MSE for shear 2 = 7.22501499694772e-05
# corr coef for shear 2 = -0.021100513637065887
#
# kernel size = 13, kernel sigma = 5
# MSE for shear 1 = 7.856077718315646e-05
# corr coef for shear 1 = -0.018480630591511726
# MSE for shear 2 = 7.046333485050127e-05
# corr coef for shear 2 = -0.02200615592300892
#
# kernel size = 13, kernel sigma = 7
# MSE for shear 1 = 7.829004607629031e-05
# corr coef for shear 1 = -0.020017070695757866
# MSE for shear 2 = 7.020458724582568e-05
# corr coef for shear 2 = -0.022593799978494644
#
# kernel size = 13, kernel sigma = 9
# MSE for shear 1 = 7.82269926276058e-05
# corr coef for shear 1 = -0.020704645663499832
# MSE for shear 2 = 7.014413131400943e-05
# corr coef for shear 2 = -0.02289445698261261
#
# kernel size = 13, kernel sigma = 11
# MSE for shear 1 = 7.820745668141171e-05
# corr coef for shear 1 = -0.021062739193439484
# MSE for shear 2 = 7.012531568761915e-05
# corr coef for shear 2 = -0.02305963635444641
#
# kernel size = 13, kernel sigma = 13
# MSE for shear 1 = 7.820023165550083e-05
# corr coef for shear 1 = -0.0212713573127985
# MSE for shear 2 = 7.011833804426715e-05
# corr coef for shear 2 = -0.023158464580774307
#
# kernel size = 13, kernel sigma = 15
# MSE for shear 1 = 7.819725578883663e-05
# corr coef for shear 1 = -0.02140313759446144
# MSE for shear 2 = 7.011542766122147e-05
# corr coef for shear 2 = -0.023221850395202637
#
# kernel size = 15, kernel sigma = 1
# MSE for shear 1 = 0.00010866512457141653
# corr coef for shear 1 = -0.016266943886876106
# MSE for shear 2 = 9.977993613574654e-05
# corr coef for shear 2 = -0.013776563107967377
#
# kernel size = 15, kernel sigma = 3
# MSE for shear 1 = 8.029982564039528e-05
# corr coef for shear 1 = -0.0152546726167202
# MSE for shear 2 = 7.211787306005135e-05
# corr coef for shear 2 = -0.02137748897075653
#
# kernel size = 15, kernel sigma = 5
# MSE for shear 1 = 7.828160596545786e-05
# corr coef for shear 1 = -0.020893670618534088
# MSE for shear 2 = 7.014223228907213e-05
# corr coef for shear 2 = -0.022973764687776566
#
# kernel size = 15, kernel sigma = 7
# MSE for shear 1 = 7.798956357873976e-05
# corr coef for shear 1 = -0.023521073162555695
# MSE for shear 2 = 6.982862396398559e-05
# corr coef for shear 2 = -0.023808231577277184
#
# kernel size = 15, kernel sigma = 9
# MSE for shear 1 = 7.792584801791236e-05
# corr coef for shear 1 = -0.02474031038582325
# MSE for shear 2 = 6.97489085723646e-05
# corr coef for shear 2 = -0.024189647287130356
#
# kernel size = 15, kernel sigma = 11
# MSE for shear 1 = 7.790835661580786e-05
# corr coef for shear 1 = -0.025384217500686646
# MSE for shear 2 = 6.97215145919472e-05
# corr coef for shear 2 = -0.02438640594482422
#
# kernel size = 15, kernel sigma = 13
# MSE for shear 1 = 7.790313247824088e-05
# corr coef for shear 1 = -0.025761863216757774
# MSE for shear 2 = 6.971000402700156e-05
# corr coef for shear 2 = -0.02449974976480007
#
# kernel size = 15, kernel sigma = 15
# MSE for shear 1 = 7.790172821842134e-05
# corr coef for shear 1 = -0.026001323014497757
# MSE for shear 2 = 6.97044306434691e-05
# corr coef for shear 2 = -0.024570712819695473

# %% [markdown]
# We plot the MSE for each kernel size and standard deviation. For both shear1 and shear2, we find that a larger kernel size is better and that the kernel standard deviation does not matter too much as long as it is at least 2.

# %%
fig, ax = plt.subplots(1, 2, figsize=(8,4))

_ = ax[0].plot(mse1)
_ = ax[0].set_ylim((5e-5,5e-4))
_ = ax[0].legend(kernel_sigmas, title = 'kernel sd')
_ = ax[0].set_xticks(ticks = torch.arange(8), labels=kernel_sizes)
_ = ax[0].set_xlabel('kernel size')
_ = ax[0].set_ylabel('MSE for shear 1')
_ = ax[0].set_yscale('log')

_ = ax[1].plot(mse2)
_ = ax[1].set_ylim((2e-5,1e-3))
_ = ax[1].legend(kernel_sigmas, title = 'kernel sd')
_ = ax[1].set_xticks(ticks = torch.arange(8), labels=kernel_sizes)
_ = ax[1].set_xlabel('kernel size')
_ = ax[1].set_ylabel('MSE for shear 2')
_ = ax[1].set_yscale('log')

fig.tight_layout()

# %% [markdown]
# We select the optimal kernel size and standard deviation based on $R^2$. We take the average of the $R^2$ for the estimated shear1 and the $R^2$ for the estimated shear2.
#
# Based on this metric, we conclude that the optimal kernel size and kernel standard deviation are both 15.

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))

_ = ax.plot(0.5 * (corr1**2) + 0.5 * (corr2**2))
_ = ax.legend(kernel_sigmas, title = 'kernel sd')
_ = ax.set_xticks(ticks = torch.arange(8), labels=kernel_sizes)
_ = ax.set_xlabel('kernel size')
_ = ax.set_ylabel('Avg R-squared of estimated shear1 and shear2')

fig.tight_layout()

# %%
fig, ax = plt.subplots(1, 2, figsize = (8,4))
_ = ax[0].scatter(shear1.flatten(), ellip1[7,2].flatten(), s = 1, alpha = 0.1, color = "sienna")
_ = ax[0].set_xlim((-0.03, 0.03))
_ = ax[0].set_ylim((-0.03, 0.03))
_ = ax[0].set_xlabel(r'True $\gamma_1$')
_ = ax[0].set_ylabel(r'$\widehat{\gamma}_1$ (baseline)')
_ = ax[0].axline((0,0), slope = 1, linestyle = ':', color = 'gray')
_ = ax[1].scatter(shear2.flatten(), ellip2[7,2].flatten(), s = 1, alpha = 0.1, color = "sienna")
_ = ax[1].set_xlim((-0.03, 0.03))
_ = ax[1].set_ylim((-0.03, 0.03))
_ = ax[1].set_xlabel(r'True $\gamma_2$')
_ = ax[1].set_ylabel(r'$\widehat{\gamma}_2$ (baseline)')
_ = ax[1].axline((0,0), slope = 1, linestyle = ':', color = 'gray')
fig.tight_layout()
