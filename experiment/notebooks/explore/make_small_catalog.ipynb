# %%
from astropy.table import Table
from bliss import HOME_DIR
import numpy as np

from bliss.datasets.lsst import prepare_final_galaxy_catalog

# %%
cat = prepare_final_galaxy_catalog()
cat
# Out:
# <Table length=575903>
#  galtileid         ra              dec         ...      z_ab          y_ab
#    int64        float64          float64       ...    float64       float64
# ------------ -------------- ------------------ ... ------------- -------------
#   2200871446 0.418319702147 -0.000148399994941 ... 23.0723800659 22.9095973969
#   2205921112 0.420028448104  -0.00100259995088 ... 25.8779563904 25.7642536163
#   2205010878 0.423432350157  -0.00312969996594 ... 25.6281528473 25.5399188995
#   2208734677  0.42108619213 -7.25999998394e-05 ... 25.9380722046 25.6458129883
#   2204477290 0.422583341599 -0.000604000000749 ... 24.9572029114 24.4631252289
#   2201104165 0.422105312347  -0.00160690001212 ... 23.0481529236  22.813867569
#   2209679020 0.426987767219  -0.00824970006943 ... 26.4114837646 26.3559627533
#   2208910365 0.428140401839  -0.00906960014254 ... 26.3757076263 26.1082286835
#   2205029524 0.426759123802  -0.00588729977608 ... 25.5596847534 25.3557510376
# ...

# %%
idx = np.random.randint(0, len(cat), 10_000)
small_cat = cat[idx]
small_cat
# Out:
# <Table length=10000>
#  galtileid          ra             dec        ...      z_ab          y_ab
#    int64         float64         float64      ...    float64       float64
# ------------ --------------- ---------------- ... ------------- -------------
#   2211496706  0.120575666427  -0.108768798411 ... 26.9086704254 26.7326755524
#   2209709991  0.285594463347  0.0537661984563 ...  26.870141983 26.8190250397
#   2207075813  0.162188887595  -0.114181399345 ... 25.8200321198 25.5431518555
# 402705628993   359.786510587  -0.124340698123 ... 25.7260837555 25.6620197296
# 402703985644   359.667429566  0.0180238001049 ... 24.5770740509 23.9333610535
# 402711454110   359.832845092   0.371727108955 ... 26.8999919891 26.9234867096
# 402709453629   359.800370455  -0.465011894703 ... 26.5340747833 26.3698806763
#   2208145675 0.0940858125661  0.0942132025957 ... 26.2916641235 26.1780776978
#   2207505555  0.428629279136  0.0724107027054 ... 25.7465057373 25.0501995087
# ...

# %%
small_cat.write(HOME_DIR / "data" / 'small_cat.fits', format='fits', overwrite=True)

# %%
small_cat2 = Table.read(HOME_DIR / "data" / "small_cat.fits")
small_cat2
# Out:
# <Table length=10000>
#  galtileid          ra             dec        ...      z_ab          y_ab
#    int64         float64         float64      ...    float64       float64
# ------------ --------------- ---------------- ... ------------- -------------
#   2211496706  0.120575666427  -0.108768798411 ... 26.9086704254 26.7326755524
#   2209709991  0.285594463347  0.0537661984563 ...  26.870141983 26.8190250397
#   2207075813  0.162188887595  -0.114181399345 ... 25.8200321198 25.5431518555
# 402705628993   359.786510587  -0.124340698123 ... 25.7260837555 25.6620197296
# 402703985644   359.667429566  0.0180238001049 ... 24.5770740509 23.9333610535
# 402711454110   359.832845092   0.371727108955 ... 26.8999919891 26.9234867096
# 402709453629   359.800370455  -0.465011894703 ... 26.5340747833 26.3698806763
#   2208145675 0.0940858125661  0.0942132025957 ... 26.2916641235 26.1780776978
#   2207505555  0.428629279136  0.0724107027054 ... 25.7465057373 25.0501995087
# ...

# %%
min(small_cat['pa_bulge'].value)
# Out:
# np.float64(0.0)
